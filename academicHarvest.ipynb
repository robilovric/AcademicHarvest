# %% [markdown]
# # **Academic Harvest**

# %% [markdown]
# Academic Harvest is a comprehensive data science project aimed at analyzing the academic landscape of FESB at Split University. Leveraging web scraping techniques and the scholarly Python library, we meticulously collected and analyzed data from Google Scholar profiles of all full-time professors at FESB. Our goal is to uncover intricate relationships between departments, identify influential professors, and highlight key metrics such as citation counts and h-indexes.

# %% [markdown]
# ### **FESB and Google Scholar**

# %% [markdown]
# FESB, located at Split University, is renowned for its excellence in engineering and maritime studies. Google Scholar serves as a vast repository of scholarly articles, providing valuable insights into the academic contributions of professors worldwide. The Scholarly Python library facilitates seamless access to Google Scholar data, enabling in-depth analysis and visualization.

# %% [markdown]
# #### *Professors and citations*

# %%
import dataInterface as data

# %%
data.plot_citations()

# %%
data.most_cited_professor()
# Out:
# The professor with the most citations is Gotovac Sven with 64602 citations.

# %% [markdown]
# #### *Citations versus publications*

# %%
data.plot_citations_vs_pubs()

# %% [markdown]
# #### Violin plot of citations versus publications

# %%
data.plot_violin()
# Out:
# c:\Users\Dell\Documents\dataScience\seminar\dataInterface.py:80: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(data=professors_df, x='num_pubs', y='num_citations', scale='width', cut=0)

# %% [markdown]
# ### *In depth professor analysis*

# %%
data.plot_collaborator_bar_plot()
# Out:
# c:\Users\Dell\Documents\dataScience\seminar\dataInterface.py:97: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Collaborator', y='Count', palette='viridis')

# %%
data.plot_collaboratorInternational_bar_plot()
# Out:
# c:\Users\Dell\Documents\dataScience\seminar\dataInterface.py:109: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Collaborator', y='Count', palette='viridis')

# %% [markdown]
# ### **At FESB caffe**

# %% [markdown]
# ![FESB Caffe](misc/caffeFESB.png)
